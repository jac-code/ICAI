# %%
import socket
import sys
import traceback
from threading import Thread

def clientThread(direccion, puerto, max_buffer_size, mensaje):       
    try:
        s = socket.socket(family=socket.AF_INET, type=socket.SOCK_STREAM)
        s.connect((direccion, puerto))
    except:
        print('Error de conexión.')
    
    print('Enviando mensaje...')
    s.sendall(mensaje.encode())
    
    data = s.recv(1024).decode()
    print(data)
    s.close()

        
puerto = 0
direccion = ''
client_id = 1

while(puerto == 0):
    try:
        print("Introduzca el número del puerto (6780 para el servidor): ")
        puerto = int(input())
        print(puerto)
    except:
        print('El puerto debe ser un numero')
        
while(direccion == ''):
    try:
        print("Introduzca la dirección del servidor ('localhost' para el servidor): ")
        direccion = (input())
        print(direccion)
    except:
        print('El puerto debe ser un numero')


lista_clientes = []
msg = ''
contador = 0

while msg != 'exit':
    msg = input('Introduzca el mensaje a enviar (exit para terminar): ')
    lista_clientes.append(msg)

print(lista_clientes)
for x in lista_clientes:
    print(x)
    try:
        Thread(target=clientThread, args=(direccion, puerto, 1024, x)).start()
    except:
        print('Error creando la hebra')
        traceback.print_exc()
# Out:
# Introduzca el mensaje a enviar (exit para terminar): hola 1
# Introduzca el mensaje a enviar (exit para terminar): hola 3
# Introduzca el mensaje a enviar (exit para terminar): hola 24343
# Introduzca el mensaje a enviar (exit para terminar): exit
# ['hola 1', 'hola 3', 'hola 24343', 'exit']
# hola 1
# hola 3
# hola 24343
# Enviando mensaje...
# exit
# Enviando mensaje...
# Enviando mensaje...
# ok
# ok
# Enviando mensaje...
# ok

# %% [markdown]
# APARTADO 2

# %%
import socket
import sys
import traceback
import threading

global threadLock 
threadLock = threading.Lock()

def clientThread(direccion, puerto, max_buffer_size, mensaje):   
    
    try:
        s = socket.socket(family=socket.AF_INET, type=socket.SOCK_STREAM)
        s.connect((direccion, puerto))
    except:
        print('Error de conexión.')
    
    threadLock.acquire(1)
    print('Enviando mensaje')
    threadLock.release()
    s.sendall(mensaje.encode())
    
    data = s.recv(1024).decode()
    threadLock.acquire(1)
    print(data)
    threadLock.release()
    s.close()

        
puerto = 6780
direccion = 'localhost'
client_id = 1

lista_clientes = []
msg = ''
contador = 0

while msg != 'exit':
    msg = input('Introduzca el mensaje a enviar (exit para terminar): ')
    lista_clientes.append(msg)

print(lista_clientes)
for x in lista_clientes:
    try:
        threading.Thread(target=clientThread, args=(direccion, puerto, 1024, x)).start()
    except:
        print('Error creando la hebra')
        traceback.print_exc()
# Out:
# Introduzca el mensaje a enviar (exit para terminar): asdasd
# Introduzca el mensaje a enviar (exit para terminar): asdsadsaad
# Introduzca el mensaje a enviar (exit para terminar): asdsadsads
# Introduzca el mensaje a enviar (exit para terminar): adsdadsadasd
# Introduzca el mensaje a enviar (exit para terminar): asdasdsad
# Introduzca el mensaje a enviar (exit para terminar): asdasdsad
# Introduzca el mensaje a enviar (exit para terminar): asd
# Introduzca el mensaje a enviar (exit para terminar):
# Introduzca el mensaje a enviar (exit para terminar): exit
# ['asdasd', 'asdsadsaad', 'asdsadsads', 'adsdadsadasd', 'asdasdsad', 'asdasdsad', 'asd', '', 'exit']
# Enviando mensaje
# Enviando mensaje
# Enviando mensaje
# ok
# ok
# Enviando mensaje
# Enviando mensaje
# ok
# Enviando mensaje
# Enviando mensaje
# ok
# Enviando mensaje
# ok
# Enviando mensaje
# ok
# ok
# Conexión terminada.
